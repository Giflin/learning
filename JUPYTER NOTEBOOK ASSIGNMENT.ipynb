# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **GIFLIN REJIN

# %% [markdown]
# Student

# %% [markdown]
# *I am interested in data science because i want to find the hidden answers in data

# %% [markdown]
# ### The following code tests the addition

# %%
a=int(input("A number="))
b=int(input("A number="))
c=a+b
print("sum is", c)
# Out:
# A number=5
# A number=6
# sum is 11

# %% [markdown]
# 1.hi
# 2.hello
# * hi
# * hello
# <a href="https://www.ibm.com/careers/us-en/search" target="_blank">hyperlinked words</a>
